# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/kltn-final/processed/all/y_test.csv
# /kaggle/input/kltn-final/processed/all/X_test.csv
# /kaggle/input/kltn-final/processed/all/y_train.csv
# /kaggle/input/kltn-final/processed/all/data_for_model.csv
# /kaggle/input/kltn-final/processed/all/X_train.csv
# /kaggle/input/kltn-final/processed/all_normalize/y_test.csv
# /kaggle/input/kltn-final/processed/all_normalize/X_test.csv
# /kaggle/input/kltn-final/processed/all_normalize/y_train.csv
# /kaggle/input/kltn-final/processed/all_normalize/data_for_model.csv
# /kaggle/input/kltn-final/processed/all_normalize/X_train.csv
# /kaggle/input/kltn-final/processed/importance/y_test.csv
# /kaggle/input/kltn-final/processed/importance/X_test.csv
# /kaggle/input/kltn-final/processed/importance/y_train.csv
# /kaggle/input/kltn-final/processed/importance/data_for_model.csv
# /kaggle/input/kltn-final/processed/importance/X_train.csv
# /kaggle/input/kltn-final/processed/importance_normalize/y_test.csv
# /kaggle/input/kltn-final/processed/importance_normalize/X_test.csv
# /kaggle/input/kltn-final/processed/importance_normalize/y_train.csv
# /kaggle/input/kltn-final/processed/importance_normalize/data_for_model.csv
# /kaggle/input/kltn-final/processed/importance_normalize/X_train.csv

# %%
import pandas as pd
import numpy as np
import cudf
from cuml.linear_model import LinearRegression
from cuml.ensemble import RandomForestRegressor
from cuml.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from cuml.model_selection import GridSearchCV
from math import sqrt
import xgboost as xgb
import lightgbm as lgb
import warnings
from sklearn.preprocessing import MinMaxScaler
warnings.filterwarnings('ignore')

# %%
def load_data(split=None):
    folder = f"/kaggle/input/kltn-final/processed/{split}"
    X_train = pd.read_csv(f"{folder}/X_train.csv")
    X_test = pd.read_csv(f"{folder}/X_test.csv")
    y_train = pd.read_csv(f"{folder}/y_train.csv")
    y_test = pd.read_csv(f"{folder}/y_test.csv")

    if 'date' in X_train.columns:
        X_train.drop('date', axis=1, inplace=True)
        X_test.drop('date', axis=1, inplace=True)

    return X_train, X_test, y_train, y_test

# %%
models = {
    'LightGBM': (lgb.LGBMRegressor(), {
        'n_estimators': [100, 200, 300], 
        'learning_rate': [0.01, 0.1, 0.2], 
        'num_leaves': [31, 63, 127]
    }),
    "Linear Regression": (LinearRegression(fit_intercept=True), {}),
    "Random Forest": (RandomForestRegressor(), {
        'n_estimators': [100, 200, 300], 
        'max_depth': [10, 20, 30], 
        'min_samples_split': [2, 5, 10]
    }),
    "XGBoost Regressor": (xgb.XGBRegressor(objective='reg:squarederror', tree_method='gpu_hist', device='cuda'), {
        'n_estimators': [100, 200, 300], 
        'max_depth': [3, 6, 9], 
        'learning_rate': [0.01, 0.1, 0.2]
    }),
    "K-Neighbors Regressor": (KNeighborsRegressor(), {
        'n_neighbors': [3, 5, 7, 9, 11, 75], 
        'weights': ['uniform', 'distance'], 
        'metric': ['euclidean', 'manhattan', 'minkowski'], 
        'algorithm': ['auto', 'ball_tree', 'kd_tree']
    })
}

# %%
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

def highlight_min(s):
    is_min = s == s.min()
    return ['background-color: green' if v else '' for v in is_min]

def sMAPE(y_test, y_pred):
    return 100 * np.mean(np.abs(y_pred - y_test) / (1 + np.abs(y_pred)))

# %%
def trainModel(split=None, scaleX=False, scaleY=False):
    # Load data
    X_train, X_test, y_train, y_test = load_data(split)

    # Scaling
    if scaleX:
        scaler = MinMaxScaler()
        X_train = pd.DataFrame(scaler.fit_transform(X_train))
        X_test =  pd.DataFrame(scaler.transform(X_test))

    scaler_y = None
    if scaleY:
        scaler_y = MinMaxScaler()
        y_train =  pd.DataFrame(scaler_y.fit_transform(y_train.values.reshape(-1, 1)))

    print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
    print(y_test.describe())

    results = {}

    for name, (model, param_grid) in models.items():
        print(name, scaleX, scaleY)
        grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_squared_error', cv=3)

        if name == 'LightGBM':
            X_train_cudf = X_train.astype('float32')
            y_train_cudf = y_train.astype('float32')
            X_test_cudf = X_test.astype('float32')
            y_test_cudf = y_test.astype('float32')
        else:
            X_train_cudf = cudf.DataFrame.from_pandas(X_train.astype('float32'))
            X_test_cudf = cudf.DataFrame.from_pandas(X_test.astype('float32'))
            y_train_cudf = y_train.values.ravel().astype('float32')
            y_test_cudf = y_test.values.ravel().astype('float32')
            
        grid_search.fit(X_train_cudf, y_train_cudf)

        best_model = grid_search.best_estimator_
        y_pred = best_model.predict(X_test_cudf)

        if hasattr(y_pred, 'to_numpy'):
            y_pred_np = y_pred.to_numpy()
        else:
            y_pred_np = np.array(y_pred)

        if scaler_y:
            y_pred = scaler_y.inverse_transform(y_pred_np.reshape(1, -1)).flatten()

        if hasattr(y_test_cudf, 'to_numpy'):
            y_test_np = y_test_cudf.to_numpy()
        else:
            y_test_np = np.array(y_test_cudf)

        mse = mean_squared_error(y_test_np, y_pred_np)
        rmse = sqrt(mse)
        r2 = r2_score(y_test_np, y_pred_np)
        mae = mean_absolute_error(y_test_np, y_pred_np)
        smape = sMAPE(y_test_np, y_pred_np)

        results[name] = {
            "Best Params": grid_search.best_params_,
            "MSE": mse,
            "RMSE": rmse,
            "R^2": r2,
            "MAE": mae,
            "sMAPE": smape
        }
    
    results_df = pd.DataFrame(results).T
    styled_df = results_df.style.apply(highlight_max, subset=['R^2']).apply(highlight_min, subset=['MSE', 'RMSE', 'MAE', 'sMAPE'])
    return styled_df, results_df

# %%
results_list = []

for data in ['all', 'all_normalize', 'importance', 'importance_normalize']:
    for scaleX in [False, True]:
        for scaleY in [False, True]:
            styled_df, results_df = trainModel(data, scaleX, scaleY)
            results_list.append((f"Data: {data}, Scale X: {scaleX}, Scale Y: {scaleY}", styled_df, results_df))
# Out:
# (73320, 44) (15275, 44) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# LightGBM False False
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029374 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030028 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029782 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026685 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027351 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028821 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029029 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027929 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030033 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027348 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028399 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028515 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027962 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030096 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028966 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034095 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027389 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029642 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032094 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028513 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030135 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027947 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028439 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029968 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028796 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030140 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029529 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036050 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029456 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027506 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034181 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032758 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036501 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034430 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033346 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034397 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032324 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033965 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034776 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032660 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032115 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029442 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033419 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032567 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030110 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034498 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031007 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028298 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030884 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032772 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035669 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033747 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033802 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038365 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032776 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034152 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036788 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034168 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.044585 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028678 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029784 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036690 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029083 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009497 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029760 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030459 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030133 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032929 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029033 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031304 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031231 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027292 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033676 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033255 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029872 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031250 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035362 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029813 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033148 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6511
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033073 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6560
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029189 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6534
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 44
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.053884 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6611
# [LightGBM] [Info] Number of data points in the train set: 73320, number of used features: 44
# [LightGBM] [Info] Start training from score 3.386211
# Linear Regression False False
# Random Forest False False
# XGBoost Regressor False False
# K-Neighbors Regressor False False
# [I] [01:37:27.949972] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [01:37
Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.077448] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.089892] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.102291] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.115816] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.128774] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.143462] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.157361] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.170170] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.182638] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.195346] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.208339] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.220673] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.232792] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.245833] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.258488] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.270784] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.283875] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.298495] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.312322] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.327208] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.341885] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.360905] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.382708] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.399913] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.416562] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.432958] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.449433] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.465517] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.481690] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.497347] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.511958] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.526462] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.540883] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.557233] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.576679] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.595260] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.613270] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.629635] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.645268] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.660782] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.677026] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.692852] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.709490] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.725604] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.741665] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.757284] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.772757] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.788031] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.803182] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.816845] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.830039] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.843609] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.857323] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.870267] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.882499] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.894742] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.907411] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.919628] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.932249] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.944387] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.956875] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.969308] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.981999] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:28.995632] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.009042] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.022726] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.036423] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.049954] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.063381] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.076838] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.089501] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.102955] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.116168] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.129622] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.143596] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.156737] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.171529] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.186099] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.202451] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.219214] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.235157] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.251135] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.266398] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.281759] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.296947] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.312911] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.328960] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.344981] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.360339] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.374515] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.389087] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.402472] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.416991] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.430467] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.443354] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.459610] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.477865] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.493974] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.508770] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.523069] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.537470] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.551591] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.565719] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.579962] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.593460] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.606752] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.620490] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.633491] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.649323] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.666829] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.684428] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.702281] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.719046] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.734584] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.750083] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.765253] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.780595] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.796269] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.811836] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.828098] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.843831] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.858681] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.872194] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.885560] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.898873] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.912015] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.925905] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.939483] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.952402] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.965455] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.979864] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:29.993451] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:30.006910] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:30.022120] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:30.046593] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [04:12:30.047265] Unused keyword parameter: n_jobs during cuML estimator initialization

# %%
# To combine all results into one DataFrame
combined_results = pd.concat([df for _, _, df in results_list], keys=[desc for desc, _, _ in results_list])
combined_results.to_csv('combined_results.csv')
print("Combined results saved to 'combined_results.csv'")
# Out:
# Combined results saved to 'combined_results.csv'

# %%
# To display the styled results in a notebook or to save them
for desc, styled_df, results_df in results_list:
    print(desc)
    display(styled_df)
# Out:
# Data: all, Scale X: False, Scale Y: False
# <style type="text/css">
# #T_0af10_row0_col1, #T_0af10_row0_col2, #T_0af10_row0_col3, #T_0af10_row2_col4, #T_0af10_row3_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_0af10">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0af10_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_0af10_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0af10_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0af10_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_0af10_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_0af10_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0af10_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_0af10_row0_col0" class="data row0 col0" >{'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}</td>
#       <td id="T_0af10_row0_col1" class="data row0 col1" >26.881076</td>
#       <td id="T_0af10_row0_col2" class="data row0 col2" >5.184696</td>
#       <td id="T_0af10_row0_col3" class="data row0 col3" >0.717462</td>
#       <td id="T_0af10_row0_col4" class="data row0 col4" >2.391982</td>
#       <td id="T_0af10_row0_col5" class="data row0 col5" >251.542567</td>
#     </tr>
#     <tr>
#       <th id="T_0af10_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_0af10_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T_0af10_row1_col1" class="data row1 col1" >94.709053</td>
#       <td id="T_0af10_row1_col2" class="data row1 col2" >9.731858</td>
#       <td id="T_0af10_row1_col3" class="data row1 col3" >0.004544</td>
#       <td id="T_0af10_row1_col4" class="data row1 col4" >5.189346</td>
#       <td id="T_0af10_row1_col5" class="data row1 col5" >115.241635</td>
#     </tr>
#     <tr>
#       <th id="T_0af10_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_0af10_row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_0af10_row2_col1" class="data row2 col1" >28.915359</td>
#       <td id="T_0af10_row2_col2" class="data row2 col2" >5.377300</td>
#       <td id="T_0af10_row2_col3" class="data row2 col3" >0.696080</td>
#       <td id="T_0af10_row2_col4" class="data row2 col4" >2.338109</td>
#       <td id="T_0af10_row2_col5" class="data row2 col5" >39.475155</td>
#     </tr>
#     <tr>
#       <th id="T_0af10_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T
td>
#     </tr>
#   </tbody>
# </table>
# Data: all, Scale X: True, Scale Y: False
# <style type="text/css">
# #T_a0654_row1_col1, #T_a0654_row1_col2, #T_a0654_row1_col3, #T_a0654_row1_col4, #T_a0654_row3_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_a0654">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0654_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_a0654_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a0654_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a0654_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_a0654_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_a0654_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0654_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_a0654_row0_col0" class="data row0 col0" >{'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}</td>
#       <td id="T_a0654_row0_col1" class="data row0 col1" >27.896429</td>
#       <td id="T_a0654_row0_col2" class="data row0 col2" >5.281707</td>
#       <td id="T_a0654_row0_col3" class="data row0 col3" >0.706790</td>
#       <td id="T_a0654_row0_col4" class="data row0 col4" >2.458210</td>
#       <td id="T_a0654_row0_col5" class="data row0 col5" >245.390293</td>
#     </tr>
#     <tr>
#       <th id="T_a0654_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_a0654_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T_a0654_row1_col1" class="data row1 col1" >26.026176</td>
#       <td id="T_a0654_row1_col2" class="data row1 col2" >5.101586</td>
#       <td id="T_a0654_row1_col3" class="data row1 col3" >0.726447</td>
#       <td id="T_a0654_row1_col4" class="data row1 col4" >2.265105</td>
#       <td id="T_a0654_row1_col5" class="data row1 col5" >38.851100</td>
#     </tr>
#     <tr>
#       <th id="T_a0654_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_a0654_row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_a0654_row2_col1" class="data row2 col1" >28.915359</td>
#       <td id="T_a0654_row2_col2" class="data row2 col2" >5.377300</td>
#       <td id="T_a0654_row2_col3" class="data row2 col3" >0.696080</td>
#       <td id="T_a0654_row2_col4" class="data row2 col4" >2.338109</td>
#       <td id="T_a0654_row2_col5" class="data row2 col5" >39.475155</td>
#     </tr>
#     <tr>
#       <th id="T_a0654_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T_a0654_row3_col0" class="data row3 col0" >{'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}</td>
#       <td id="T_a0654_row3_col1" class="data row3 col1" >33.160446</td>
#       <td id="T_a0654_row3_col2" class="data row3 col2" >5.758511</td>
#       <td id="T_a0654_row3_col3" class="data row3 col3" >0.651461</td>
#       <td id="T_a0654_row3_col4" class="data row3 col4" >2.687541</td>
#       <td id="T_a0654_row3_col5" class="data row3 col5" >36.759105</td>
#     </tr>
#     <tr>
#       <th id="T_a0654_level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T_a0654_row4_col0" class="data row4 col0" >{'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}</td>
#       <td id="T_a0654_row4_col1" class="data row4 col1" >30.549044</td>
#       <td id="T_a0654_row4_col2" class="data row4 col2" >5.527119</td>
#       <td id="T_a0654_row4_col3" class="data row4 col3" >0.678909</td>
#       <td id="T_a0654_row4_col4" class="data row4 col4" >2.366874</td>
#       <td id="T_a0654_row4_col5" class="data row4 col5" >46.457592</td>
#     </tr>
#   </tbody>
# </table>
# Data: all, Scale X: True, Scale Y: True
# <style type="text/css">
# #T_933c0_row3_col1, #T_933c0_row3_col2, #T_933c0_row3_col3, #T_933c0_row3_col4, #T_933c0_row3_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_933c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_933c0_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_933c0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_933c0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_933c0_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_933c0_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_933c0_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_933c0_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_933c0_row0_col0" class="data row0 col0" >{'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}</td>
#       <td id="T_933c0_row0_col1" class="data row0 col1" >113.216843</td>
#       <td id="T_933c0_row0_col2" class="data row0 col2" >10.640340</td>
#       <td id="T_933c0_row0_col3" class="data row0 col3" >-0.189985</td>
#       <td id="T_933c0_row0_col4" class="data row0 col4" >4.472469</td>
#       <td id="T_933c0_row0_col5" class="data row0 col5" >430.330370</td>
#     </tr>
#     <tr>
#       <th id="T_933c0_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_933c0_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T
level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T_7f863_row4_col0" class="data row4 col0" >{'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}</td>
#       <td id="T_7f863_row4_col1" class="data row4 col1" >56.283535</td>
#       <td id="T_7f863_row4_col2" class="data row4 col2" >7.502235</td>
#       <td id="T_7f863_row4_col3" class="data row4 col3" >0.408422</td>
#       <td id="T_7f863_row4_col4" class="data row4 col4" >3.225554</td>
#       <td id="T_7f863_row4_col5" class="data row4 col5" >79.133230</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance, Scale X: False, Scale Y: True
# <style type="text/css">
# #T_ff521_row2_col1, #T_ff521_row2_col2, #T_ff521_row2_col3, #T_ff521_row2_col4, #T_ff521_row2_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_ff521">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff521_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_ff521_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ff521_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ff521_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_ff521_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_ff521_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff521_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_ff521_row0_col0" class="data row0 col0" >{'learning_rate': 0.01, 'n_estimators': 300, 'num_leaves': 31}</td>
#       <td id="T_ff521_row0_col1" class="data row0 col1" >113.872406</td>
#       <td id="T_ff521_row0_col2" class="data row0 col2" >10.671101</td>
#       <td id="T_ff521_row0_col3" class="data row0 col3" >-0.196875</td>
#       <td id="T_ff521_row0_col4" class="data row0 col4" >4.488488</td>
#       <td id="T_ff521_row0_col5" class="data row0 col5" >434.916325</td>
#     </tr>
#     <tr>
#       <th id="T_ff521_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_ff521_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T_ff521_row1_col1" class="data row1 col1" >114.678558</td>
#       <td id="T_ff521_row1_col2" class="data row1 col2" >10.708808</td>
#       <td id="T_ff521_row1_col3" class="data row1 col3" >-0.205349</td>
#       <td id="T_ff521_row1_col4" class="data row1 col4" >4.506323</td>
#       <td id="T_ff521_row1_col5" class="data row1 col5" >409.272432</td>
#     </tr>
#     <tr>
#       <th id="T_ff521_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_ff521_row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_ff521_row2_col1" class="data row2 col1" >113.804138</td>
#       <td id="T_ff521_row2_col2" class="data row2 col2" >10.667902</td>
#       <td id="T_ff521_row2_col3" class="data row2 col3" >-0.196158</td>
#       <td id="T_ff521_row2_col4" class="data row2 col4" >4.486054</td>
#       <td id="T_ff521_row2_col5" class="data row2 col5" >377.532172</td>
#     </tr>
#     <tr>
#       <th id="T_ff521_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T_ff521_row3_col0" class="data row3 col0" >{'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 300}</td>
#       <td id="T_ff521_row3_col1" class="data row3 col1" >113.873520</td>
#       <td id="T_ff521_row3_col2" class="data row3 col2" >10.671154</td>
#       <td id="T_ff521_row3_col3" class="data row3 col3" >-0.196887</td>
#       <td id="T_ff521_row3_col4" class="data row3 col4" >4.488148</td>
#       <td id="T_ff521_row3_col5" class="data row3 col5" >379.793644</td>
#     </tr>
#     <tr>
#       <th id="T_ff521_level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T_ff521_row4_col0" class="data row4 col0" >{'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}</td>
#       <td id="T_ff521_row4_col1" class="data row4 col1" >114.405807</td>
#       <td id="T_ff521_row4_col2" class="data row4 col2" >10.696065</td>
#       <td id="T_ff521_row4_col3" class="data row4 col3" >-0.202482</td>
#       <td id="T_ff521_row4_col4" class="data row4 col4" >4.500057</td>
#       <td id="T_ff521_row4_col5" class="data row4 col5" >399.993300</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance, Scale X: True, Scale Y: False
# <style type="text/css">
# #T_dee2d_row1_col1, #T_dee2d_row1_col2, #T_dee2d_row1_col3, #T_dee2d_row1_col4, #T_dee2d_row2_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_dee2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dee2d_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_dee2d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_dee2d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_dee2d_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_dee2d_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_dee2d_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dee2d_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_dee2d_row0_col0" class="data row0 col0" >{'learning_rate': 0.01, 'n_estimators': 300, 'num_leaves':