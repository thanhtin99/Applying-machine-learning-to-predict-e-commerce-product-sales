# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import GridSearchCV
from math import sqrt
import xgboost as xgb
import lightgbm as lgb
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeRegressor
warnings.filterwarnings('ignore')

# %%
# Load data function
def load_data(split=None):
    folder = f"../data/processed/{split}"
    X_train = pd.read_csv(f"{folder}/X_train.csv")
    X_test = pd.read_csv(f"{folder}/X_test.csv")
    y_train = pd.read_csv(f"{folder}/y_train.csv")
    y_test = pd.read_csv(f"{folder}/y_test.csv")

    if 'date' in X_train.columns:
        X_train.drop('date', axis=1, inplace=True)
        X_test.drop('date', axis=1, inplace=True)

    # if 'itemid' in X_train.columns:
    #     X_train.drop('itemid', axis=1, inplace=True)
    #     X_test.drop('itemid', axis=1, inplace=True)
        
    # X_train.drop('label_1_count', axis=1, inplace=True)
    # X_test.drop('label_1_count', axis=1, inplace=True)
    return X_train, X_test, y_train, y_test

# %%
# Models and parameters
models = {
    "Decision Tree Regressor": (DecisionTreeRegressor(), {
        'max_depth': [None, 10, 20, 30], 
        'min_samples_split': [2, 5, 10], 
        'min_samples_leaf': [1, 2, 4]
    })
}

# %%
# Highlight functions
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

def highlight_min(s):
    is_min = s == s.min()
    return ['background-color: green' if v else '' for v in is_min]

def sMAPE(y_test, y_pred):
    return 100 * np.mean(np.abs(y_pred - y_test) / (1 + np.abs(y_pred)))

# %%
# Train model function
def trainModel(split=None, scaleX=False, scaleY=False):
    # Load data
    X_train, X_test, y_train, y_test = load_data(split)

    # Scaling
    if scaleX:
        scaler = MinMaxScaler()
        X_train = pd.DataFrame(scaler.fit_transform(X_train))
        X_test =  pd.DataFrame(scaler.transform(X_test))

    scaler_y = None
    if scaleY:
        scaler_y = MinMaxScaler()
        y_train =  pd.DataFrame(scaler_y.fit_transform(y_train.values.reshape(-1, 1)))

    print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
    print(y_test.describe())

    results = {}

    for name, (model, param_grid) in models.items():
        print(name, scaleX, scaleY)
        grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_squared_error', cv=3)
        grid_search.fit(X_train, y_train.values.ravel())

        best_model = grid_search.best_estimator_
        y_pred = best_model.predict(X_test)

        if scaler_y:
            y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).flatten()

        y_test_np = y_test.values.ravel()
        y_pred_np = y_pred.ravel()

        mse = mean_squared_error(y_test_np, y_pred_np)
        rmse = sqrt(mse)
        r2 = r2_score(y_test_np, y_pred_np)
        mae = mean_absolute_error(y_test_np, y_pred_np)
        smape = sMAPE(y_test_np, y_pred_np)

        results[name] = {
            "Best Params": grid_search.best_params_,
            "MSE": mse,
            "RMSE": rmse,
            "R^2": r2,
            "MAE": mae,
            "sMAPE": smape
        }
    
    results_df = pd.DataFrame(results).T
    styled_df = results_df.style.apply(highlight_max, subset=['R^2']).apply(highlight_min, subset=['MSE', 'RMSE', 'MAE', 'sMAPE'])
    return styled_df, results_df

# %%
# Run training for different configurations
results_list = []

for data in ['all', 'all_normalize', 'importance', 'importance_normalize']:
    for scaleX in [False, True]:
        for scaleY in [False, True]:
            styled_df, results_df = trainModel(data, scaleX, scaleY)
            results_list.append((f"Data: {data}, Scale X: {scaleX}, Scale Y: {scaleY}", styled_df, results_df))
# Out:
# (73320, 43) (15275, 43) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor False False
# (73320, 43) (15275, 43) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor False True
# (73320, 43) (15275, 43) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor True False
# (73320, 43) (15275, 43) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor True True
# (73320, 43) (15275, 43) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor False False
# (73320, 43) (15275, 43) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor False True
# (73320, 43) (15275, 43) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor True False
# (73320, 43) (15275, 43) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor True True
# (73320, 23) (15275, 23) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor False False
# (73320, 23) (15275, 23) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor False True
# (73320, 23) (15275, 23) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor True False
# (73320, 23) (15275, 23) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor True True
# (73320, 28) (15275, 28) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor False False
# (73320, 28) (15275, 28) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor False True
# (73320, 28) (15275, 28) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor True False
# (73320, 28) (15275, 28) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# Decision Tree Regressor True True

# %%
# Combine all results into one DataFrame
combined_results = pd.concat([df for _, _, df in results_list], keys=[desc for desc, _, _ in results_list])
combined_results.to_csv('tree_keeplabel1.csv')
print("Combined results saved to 'combined_results.csv'")
# Out:
# Combined results saved to 'combined_results.csv'

# %%
# Display the styled results in a notebook or to save them
for desc, styled_df, results_df in results_list:
    print(desc)
    display(styled_df)
# Out:
# Data: all, Scale X: False, Scale Y: False
# <style type="text/css">
# #T_c455e_row0_col1, #T_c455e_row0_col2, #T_c455e_row0_col3, #T_c455e_row0_col4, #T_c455e_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_c455e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c455e_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_c455e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c455e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c455e_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_c455e_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_c455e_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c455e_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_c455e_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_c455e_row0_col1" class="data row0 col1" >48.566494</td>
#       <td id="T_c455e_row0_col2" class="data row0 col2" >6.968967</td>
#       <td id="T_c455e_row0_col3" class="data row0 col3" >0.489534</td>
#       <td id="T_c455e_row0_col4" class="data row0 col4" >2.980311</td>
#       <td id="T_c455e_row0_col5" class="data row0 col5" >42.174604</td>
#     </tr>
#   </tbody>
# </table>
# Data: all, Scale X: False, Scale Y: True
# <style type="text/css">
# #T_e85c3_row0_col1, #T_e85c3_row0_col2, #T_e85c3_row0_col3, #T_e85c3_row0_col4, #T_e85c3_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_e85c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e85c3_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_e85c3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_e85c3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_e85c3_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_e85c3_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_e85c3_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e85c3_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_e85c3_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_e85c3_row0_col1" class="data row0 col1" >48.650000</td>
#       <td id="T_e85c3_row0_col2" class="data row0 col2" >6.974955</td>
#       <td id="T_e85c3_row0_col3" class="data row0 col3" >0.488656</td>
#       <td id="T_e85c3_row0_col4" class="data row0 col4" >2.976622</td>
#       <td id="T_e85c3_row0_col5" class="data row0 col5" >42.173681</td>
#     </tr>
#   </tbody>
# </table>
# Data: all, Scale X: True, Scale Y: False
# <style type="text/css">
# #T_da0f4_row0_col1, #T_da0f4_row0_col2, #T_da0f4_row0_col3, #T_da0f4_row0_col4, #T_da0f4_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_da0f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da0f4_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_da0f4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_da0f4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_da0f4_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_da0f4_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_da0f4_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da0f4_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_da0f4_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_da0f4_row0_col1" class="data row0 col1" >48.659048</td>
#       <td id="T_da0f4_row0_col2" class="data row0 col2" >6.975604</td>
#       <td id="T_da0f4_row0_col3" class="data row0 col3" >0.488561</td>
#       <td id="T_da0f4_row0_col4" class="data row0 col4" >2.980347</td>
#       <td id="T_da0f4_row0_col5" class="data row0 col5" >42.138920</td>
#     </tr>
#   </tbody>
# </table>
# Data: all, Scale X: True, Scale Y: True
# <style type="text/css">
# #T_b5b21_row0_col1, #T_b5b21_row0_col2, #T_b5b21_row0_col3, #T_b5b21_row0_col4, #T_b5b21_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_b5b21">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5b21_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_b5b21_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b5b21_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b5b21_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_b5b21_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_b5b21_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5b21_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_b5b21_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_b5b21_row0_col1" class="data row0 col1" >48.562511</td>
#       <td id="T_b5b21_row0_col2" class="data row0 col2" >6.968681</td>
#       <td id="T_b5b21_row0_col3" class="data row0 col3" >0.489575</td>
#       <td id="T_b5b21_row0_col4" class="data row0 col4" >2.978532</td>
#       <td id="T_b5b21_row0_col5" class="data row0 col5" >42.147676</td>
#     </tr>
#   </tbody>
# </table>
# Data: all_normalize, Scale X: False, Scale Y: False
# <style type="text/css">
# #T_426b2_row0_col1, #T_426b2_row0_col2, #T_426b2_row0_col3, #T_426b2_row0_col4, #T_426b2_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_426b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_426b2_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_426b2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_426b2_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_426b2_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_426b2_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_426b2_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_426b2_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_426b2_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2}</td>
#       <td id="T_426b2_row0_col1" class="data row0 col1" >50.131526</td>
#       <td id="T_426b2_row0_col2" class="data row0 col2" >7.080362</td>
#       <td id="T_426b2_row0_col3" class="data row0 col3" >0.473084</td>
#       <td id="T_426b2_row0_col4" class="data row0 col4" >2.995934</td>
#       <td id="T_426b2_row0_col5" class="data row0 col5" >42.330626</td>
#     </tr>
#   </tbody>
# </table>
# Data: all_normalize, Scale X: False, Scale Y: True
# <style type="text/css">
# #T_f0d3e_row0_col1, #T_f0d3e_row0_col2, #T_f0d3e_row0_col3, #T_f0d3e_row0_col4, #T_f0d3e_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_f0d3e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0d3e_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_f0d3e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f0d3e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f0d3e_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_f0d3e_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_f0d3e_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0d3e_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_f0d3e_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_f0d3e_row0_col1" class="data row0 col1" >48.811141</td>
#       <td id="T_f0d3e_row0_col2" class="data row0 col2" >6.986497</td>
#       <td id="T_f0d3e_row0_col3" class="data row0 col3" >0.486962</td>
#       <td id="T_f0d3e_row0_col4" class="data row0 col4" >2.981065</td>
#       <td id="T_f0d3e_row0_col5" class="data row0 col5" >42.141685</td>
#     </tr>
#   </tbody>
# </table>
# Data: all_normalize, Scale X: True, Scale Y: False
# <style type="text/css">
# #T_49931_row0_col1, #T_49931_row0_col2, #T_49931_row0_col3, #T_49931_row0_col4, #T_49931_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_49931">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49931_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_49931_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_49931_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_49931_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_49931_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_49931_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49931_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_49931_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2}</td>
#       <td id="T_49931_row0_col1" class="data row0 col1" >49.255456</td>
#       <td id="T_49931_row0_col2" class="data row0 col2" >7.018223</td>
#       <td id="T_49931_row0_col3" class="data row0 col3" >0.482292</td>
#       <td id="T_49931_row0_col4" class="data row0 col4" >2.979533</td>
#       <td id="T_49931_row0_col5" class="data row0 col5" >42.185857</td>
#     </tr>
#   </tbody>
# </table>
# Data: all_normalize, Scale X: True, Scale Y: True
# <style type="text/css">
# #T_addfd_row0_col1, #T_addfd_row0_col2, #T_addfd_row0_col3, #T_addfd_row0_col4, #T_addfd_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_addfd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_addfd_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_addfd_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_addfd_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_addfd_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_addfd_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_addfd_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_addfd_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_addfd_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_addfd_row0_col1" class="data row0 col1" >49.232610</td>
#       <td id="T_addfd_row0_col2" class="data row0 col2" >7.016595</td>
#       <td id="T_addfd_row0_col3" class="data row0 col3" >0.482532</td>
#       <td id="T_addfd_row0_col4" class="data row0 col4" >2.991665</td>
#       <td id="T_addfd_row0_col5" class="data row0 col5" >42.172832</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance, Scale X: False, Scale Y: False
# <style type="text/css">
# #T_96098_row0_col1, #T_96098_row0_col2, #T_96098_row0_col3, #T_96098_row0_col4, #T_96098_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_96098">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96098_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_96098_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_96098_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_96098_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_96098_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_96098_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96098_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_96098_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_96098_row0_col1" class="data row0 col1" >32.244336</td>
#       <td id="T_96098_row0_col2" class="data row0 col2" >5.678410</td>
#       <td id="T_96098_row0_col3" class="data row0 col3" >0.661090</td>
#       <td id="T_96098_row0_col4" class="data row0 col4" >2.390857</td>
#       <td id="T_96098_row0_col5" class="data row0 col5" >40.430353</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance, Scale X: False, Scale Y: True
# <style type="text/css">
# #T_de121_row0_col1, #T_de121_row0_col2, #T_de121_row0_col3, #T_de121_row0_col4, #T_de121_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_de121">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de121_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_de121_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_de121_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_de121_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_de121_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_de121_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de121_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_de121_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_de121_row0_col1" class="data row0 col1" >32.223046</td>
#       <td id="T_de121_row0_col2" class="data row0 col2" >5.676535</td>
#       <td id="T_de121_row0_col3" class="data row0 col3" >0.661314</td>
#       <td id="T_de121_row0_col4" class="data row0 col4" >2.390924</td>
#       <td id="T_de121_row0_col5" class="data row0 col5" >40.448876</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance, Scale X: True, Scale Y: False
# <style type="text/css">
# #T_3861a_row0_col1, #T_3861a_row0_col2, #T_3861a_row0_col3, #T_3861a_row0_col4, #T_3861a_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_3861a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3861a_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_3861a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3861a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3861a_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_3861a_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_3861a_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3861a_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_3861a_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_3861a_row0_col1" class="data row0 col1" >32.160850</td>
#       <td id="T_3861a_row0_col2" class="data row0 col2" >5.671054</td>
#       <td id="T_3861a_row0_col3" class="data row0 col3" >0.661968</td>
#       <td id="T_3861a_row0_col4" class="data row0 col4" >2.389053</td>
#       <td id="T_3861a_row0_col5" class="data row0 col5" >40.446408</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance, Scale X: True, Scale Y: True
# <style type="text/css">
# #T_85157_row0_col1, #T_85157_row0_col2, #T_85157_row0_col3, #T_85157_row0_col4, #T_85157_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_85157">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85157_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_85157_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_85157_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_85157_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_85157_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_85157_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85157_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_85157_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_85157_row0_col1" class="data row0 col1" >32.225019</td>
#       <td id="T_85157_row0_col2" class="data row0 col2" >5.676708</td>
#       <td id="T_85157_row0_col3" class="data row0 col3" >0.661293</td>
#       <td id="T_85157_row0_col4" class="data row0 col4" >2.391107</td>
#       <td id="T_85157_row0_col5" class="data row0 col5" >40.444292</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance_normalize, Scale X: False, Scale Y: False
# <style type="text/css">
# #T_bbff9_row0_col1, #T_bbff9_row0_col2, #T_bbff9_row0_col3, #T_bbff9_row0_col4, #T_bbff9_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_bbff9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbff9_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_bbff9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bbff9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bbff9_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_bbff9_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_bbff9_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbff9_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_bbff9_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_bbff9_row0_col1" class="data row0 col1" >31.362980</td>
#       <td id="T_bbff9_row0_col2" class="data row0 col2" >5.600266</td>
#       <td id="T_bbff9_row0_col3" class="data row0 col3" >0.670354</td>
#       <td id="T_bbff9_row0_col4" class="data row0 col4" >2.370660</td>
#       <td id="T_bbff9_row0_col5" class="data row0 col5" >40.203631</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance_normalize, Scale X: False, Scale Y: True
# <style type="text/css">
# #T_b1145_row0_col1, #T_b1145_row0_col2, #T_b1145_row0_col3, #T_b1145_row0_col4, #T_b1145_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_b1145">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1145_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_b1145_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b1145_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b1145_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_b1145_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_b1145_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1145_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_b1145_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_b1145_row0_col1" class="data row0 col1" >31.859590</td>
#       <td id="T_b1145_row0_col2" class="data row0 col2" >5.644430</td>
#       <td id="T_b1145_row0_col3" class="data row0 col3" >0.665134</td>
#       <td id="T_b1145_row0_col4" class="data row0 col4" >2.376896</td>
#       <td id="T_b1145_row0_col5" class="data row0 col5" >40.235717</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance_normalize, Scale X: True, Scale Y: False
# <style type="text/css">
# #T_3d554_row0_col1, #T_3d554_row0_col2, #T_3d554_row0_col3, #T_3d554_row0_col4, #T_3d554_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_3d554">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d554_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_3d554_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3d554_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3d554_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_3d554_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_3d554_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d554_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_3d554_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_3d554_row0_col1" class="data row0 col1" >31.609455</td>
#       <td id="T_3d554_row0_col2" class="data row0 col2" >5.622229</td>
#       <td id="T_3d554_row0_col3" class="data row0 col3" >0.667763</td>
#       <td id="T_3d554_row0_col4" class="data row0 col4" >2.371850</td>
#       <td id="T_3d554_row0_col5" class="data row0 col5" >40.215802</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance_normalize, Scale X: True, Scale Y: True
# <style type="text/css">
# #T_29427_row0_col1, #T_29427_row0_col2, #T_29427_row0_col3, #T_29427_row0_col4, #T_29427_row0_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_29427">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29427_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_29427_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_29427_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_29427_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_29427_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_29427_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29427_level0_row0" class="row_heading level0 row0" >Decision Tree Regressor</th>
#       <td id="T_29427_row0_col0" class="data row0 col0" >{'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}</td>
#       <td id="T_29427_row0_col1" class="data row0 col1" >31.855972</td>
#       <td id="T_29427_row0_col2" class="data row0 col2" >5.644109</td>
#       <td id="T_29427_row0_col3" class="data row0 col3" >0.665172</td>
#       <td id="T_29427_row0_col4" class="data row0 col4" >2.377079</td>
#       <td id="T_29427_row0_col5" class="data row0 col5" >40.245834</td>
#     </tr>
#   </tbody>
# </table>
