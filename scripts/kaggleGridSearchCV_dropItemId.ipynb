# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/kltn-final/processed/all/y_test.csv
# /kaggle/input/kltn-final/processed/all/X_test.csv
# /kaggle/input/kltn-final/processed/all/y_train.csv
# /kaggle/input/kltn-final/processed/all/data_for_model.csv
# /kaggle/input/kltn-final/processed/all/X_train.csv
# /kaggle/input/kltn-final/processed/all_normalize/y_test.csv
# /kaggle/input/kltn-final/processed/all_normalize/X_test.csv
# /kaggle/input/kltn-final/processed/all_normalize/y_train.csv
# /kaggle/input/kltn-final/processed/all_normalize/data_for_model.csv
# /kaggle/input/kltn-final/processed/all_normalize/X_train.csv
# /kaggle/input/kltn-final/processed/importance/y_test.csv
# /kaggle/input/kltn-final/processed/importance/X_test.csv
# /kaggle/input/kltn-final/processed/importance/y_train.csv
# /kaggle/input/kltn-final/processed/importance/data_for_model.csv
# /kaggle/input/kltn-final/processed/importance/X_train.csv
# /kaggle/input/kltn-final/processed/importance_normalize/y_test.csv
# /kaggle/input/kltn-final/processed/importance_normalize/X_test.csv
# /kaggle/input/kltn-final/processed/importance_normalize/y_train.csv
# /kaggle/input/kltn-final/processed/importance_normalize/data_for_model.csv
# /kaggle/input/kltn-final/processed/importance_normalize/X_train.csv

# %%
import pandas as pd
import numpy as np
import cudf
from cuml.linear_model import LinearRegression
from cuml.ensemble import RandomForestRegressor
from cuml.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from cuml.model_selection import GridSearchCV
from math import sqrt
import xgboost as xgb
import lightgbm as lgb
import warnings
from sklearn.preprocessing import MinMaxScaler
warnings.filterwarnings('ignore')

# %%
def load_data(split=None):
    folder = f"/kaggle/input/kltn-final/processed/{split}"
    X_train = pd.read_csv(f"{folder}/X_train.csv")
    X_test = pd.read_csv(f"{folder}/X_test.csv")
    y_train = pd.read_csv(f"{folder}/y_train.csv")
    y_test = pd.read_csv(f"{folder}/y_test.csv")

    if 'date' in X_train.columns:
        X_train.drop('date', axis=1, inplace=True)
        X_test.drop('date', axis=1, inplace=True)
    if 'itemid' in X_train.columns:
        X_train.drop('itemid', axis=1, inplace=True)
        X_test.drop('itemid', axis=1, inplace=True)

    return X_train, X_test, y_train, y_test

# %%
models = {
    'LightGBM': (lgb.LGBMRegressor(), {
        'n_estimators': [100, 200, 300], 
        'learning_rate': [0.01, 0.1, 0.2], 
        'num_leaves': [31, 63, 127]
    }),
    "Linear Regression": (LinearRegression(fit_intercept=True), {}),
    "Random Forest": (RandomForestRegressor(), {
        'n_estimators': [100, 200, 300], 
        'max_depth': [10, 20, 30], 
        'min_samples_split': [2, 5, 10]
    }),
    "XGBoost Regressor": (xgb.XGBRegressor(objective='reg:squarederror', tree_method='gpu_hist', device='cuda'), {
        'n_estimators': [100, 200, 300], 
        'max_depth': [3, 6, 9], 
        'learning_rate': [0.01, 0.1, 0.2]
    }),
    "K-Neighbors Regressor": (KNeighborsRegressor(), {
        'n_neighbors': [3, 5, 7, 9, 11, 75], 
        'weights': ['uniform', 'distance'], 
        'metric': ['euclidean', 'manhattan', 'minkowski'], 
        'algorithm': ['auto', 'ball_tree', 'kd_tree']
    })
}

# %%
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

def highlight_min(s):
    is_min = s == s.min()
    return ['background-color: green' if v else '' for v in is_min]

def sMAPE(y_test, y_pred):
    return 100 * np.mean(np.abs(y_pred - y_test) / (1 + np.abs(y_pred)))

# %%
def trainModel(split=None, scaleX=False, scaleY=False):
    # Load data
    X_train, X_test, y_train, y_test = load_data(split)

    # Scaling
    if scaleX:
        scaler = MinMaxScaler()
        X_train = pd.DataFrame(scaler.fit_transform(X_train))
        X_test =  pd.DataFrame(scaler.transform(X_test))

    scaler_y = None
    if scaleY:
        scaler_y = MinMaxScaler()
        y_train =  pd.DataFrame(scaler_y.fit_transform(y_train.values.reshape(-1, 1)))

    print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
    print(y_test.describe())

    results = {}

    for name, (model, param_grid) in models.items():
        print(name, scaleX, scaleY)
        grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_squared_error', cv=3)

        if name == 'LightGBM':
            X_train_cudf = X_train.astype('float32')
            y_train_cudf = y_train.astype('float32')
            X_test_cudf = X_test.astype('float32')
            y_test_cudf = y_test.astype('float32')
        else:
            X_train_cudf = cudf.DataFrame.from_pandas(X_train.astype('float32'))
            X_test_cudf = cudf.DataFrame.from_pandas(X_test.astype('float32'))
            y_train_cudf = y_train.values.ravel().astype('float32')
            y_test_cudf = y_test.values.ravel().astype('float32')
            
        grid_search.fit(X_train_cudf, y_train_cudf)

        best_model = grid_search.best_estimator_
        y_pred = best_model.predict(X_test_cudf)

        if hasattr(y_pred, 'to_numpy'):
            y_pred_np = y_pred.to_numpy()
        else:
            y_pred_np = np.array(y_pred)

        if scaler_y:
            y_pred = scaler_y.inverse_transform(y_pred_np.reshape(1, -1)).flatten()

        if hasattr(y_test_cudf, 'to_numpy'):
            y_test_np = y_test_cudf.to_numpy()
        else:
            y_test_np = np.array(y_test_cudf)

        mse = mean_squared_error(y_test_np, y_pred_np)
        rmse = sqrt(mse)
        r2 = r2_score(y_test_np, y_pred_np)
        mae = mean_absolute_error(y_test_np, y_pred_np)
        smape = sMAPE(y_test_np, y_pred_np)

        results[name] = {
            "Best Params": grid_search.best_params_,
            "MSE": mse,
            "RMSE": rmse,
            "R^2": r2,
            "MAE": mae,
            "sMAPE": smape
        }
    
    results_df = pd.DataFrame(results).T
    styled_df = results_df.style.apply(highlight_max, subset=['R^2']).apply(highlight_min, subset=['MSE', 'RMSE', 'MAE', 'sMAPE'])
    return styled_df, results_df

# %%
results_list = []

for data in ['all', 'all_normalize', 'importance', 'importance_normalize']:
    for scaleX in [False, True]:
        for scaleY in [False, True]:
            styled_df, results_df = trainModel(data, scaleX, scaleY)
            results_list.append((f"Data: {data}, Scale X: {scaleX}, Scale Y: {scaleY}", styled_df, results_df))
# Out:
# (73320, 43) (15275, 43) (73320, 1) (15275, 1)
#        sales_predict_day
# count       15275.000000
# mean            4.527660
# std             9.754365
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             4.000000
# max            86.000000
# LightGBM False False
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033476 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029514 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031528 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023197 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022805 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033007 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023131 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022417 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025227 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023478 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023125 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022499 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023106 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022417 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022806 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022833 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029438 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024110 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022970 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023207 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023644 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022818 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023334 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012920 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022560 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023162 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022539 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023315 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023056 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022716 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023123 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024296 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022844 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022378 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024331 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022252 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023772 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022818 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022380 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022626 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022479 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029033 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022572 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022953 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022956 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022804 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023119 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022302 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023160 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022624 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022744 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023889 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023888 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022147 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026627 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023136 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023113 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022647 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022670 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023154 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6256
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.378417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023125 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6305
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.459493
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022462 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6279
# [LightGBM] [Info] Number of data points in the train set: 48880, number of used features: 43
# [LightGBM] [Info] Start training from score 3.320724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.
Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.139617] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.151295] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.163092] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.174767] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.186897] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.198613] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.211395] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.223298] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.235565] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.247256] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.259067] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.270798] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.282481] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.294178] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.305927] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.318641] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.330410] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.342136] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.353808] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.366737] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.378425] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.390168] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.401946] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.415129] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.427124] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.439141] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.450835] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.463482] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.475239] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.487029] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.498950] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.512147] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.524081] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.535977] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.547727] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.559725] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.571980] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.583693] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.595377] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.607214] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.620048] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.632034] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.643807] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.655628] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.667549] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.679583] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.691318] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.704746] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.718688] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.730524] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.742326] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.754070] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.765850] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.778181] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.789895] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.801628] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.813357] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.826478] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.838516] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.850272] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.862052] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.878665] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.894863] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.909597] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.924601] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.936915] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.948929] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.960756] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.972537] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.984422] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:18.996137] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.007893] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.019565] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.032861] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.044844] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.056514] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.068196] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.079972] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.091598] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.103325] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.114949] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.126753] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.138447] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.150087] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.161865] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.173521] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.185216] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.196963] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.208621] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.220266] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.232245] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.244455] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.256440] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.268190] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.279996] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.291675] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.303351] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.315010] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.327910] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.339603] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.351268] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.363198] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.374879] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.386621] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.398377] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.410087] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.422161] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.434459] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.447254] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.459305] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.470905] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.483014] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.495176] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.507012] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.520991] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.536690] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.552674] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.569799] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.584384] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.596712] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.609041] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.621123] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.633378] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.645390] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.661893] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.678904] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.695127] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.709304] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.721226] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.733149] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.745600] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.757398] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.769419] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.781573] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.796328] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.808255] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.820175] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.832106] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.844141] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.856041] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.868939] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.881289] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.893699] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.906304] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.919678] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.936084] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.949364] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.961415] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.973788] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.985722] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:19.997807] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.009724] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.021494] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.033350] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.045229] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.057090] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.068909] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.081988] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.094390] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.106355] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.127167] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.138906] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.150768] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.162676] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.174433] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.186319] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.198229] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.210003] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.221721] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.233784] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.253536] Unused keyword parameter: n_jobs during cuML estimator initialization
# [I] [07:02:20.253997] Unused keyword parameter: n_jobs during cuML estimator initialization

# %%
# To combine all results into one DataFrame
combined_results = pd.concat([df for _, _, df in results_list], keys=[desc for desc, _, _ in results_list])
combined_results.to_csv('combined_results.csv')
print("Combined results saved to 'combined_results.csv'")
# Out:
# Combined results saved to 'combined_results.csv'

# %%
# To display the styled results in a notebook or to save them
for desc, styled_df, results_df in results_list:
    print(desc)
    display(styled_df)
# Out:
# Data: all, Scale X: False, Scale Y: False
# <style type="text/css">
# #T_6696a_row0_col1, #T_6696a_row0_col2, #T_6696a_row0_col3, #T_6696a_row2_col4, #T_6696a_row3_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_6696a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6696a_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_6696a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6696a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6696a_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_6696a_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_6696a_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6696a_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_6696a_row0_col0" class="data row0 col0" >{'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}</td>
#       <td id="T_6696a_row0_col1" class="data row0 col1" >27.703377</td>
#       <td id="T_6696a_row0_col2" class="data row0 col2" >5.263400</td>
#       <td id="T_6696a_row0_col3" class="data row0 col3" >0.708819</td>
#       <td id="T_6696a_row0_col4" class="data row0 col4" >2.439685</td>
#       <td id="T_6696a_row0_col5" class="data row0 col5" >244.489418</td>
#     </tr>
#     <tr>
#       <th id="T_6696a_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_6696a_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T_6696a_row1_col1" class="data row1 col1" >76.941719</td>
#       <td id="T_6696a_row1_col2" class="data row1 col2" >8.771643</td>
#       <td id="T_6696a_row1_col3" class="data row1 col3" >0.191291</td>
#       <td id="T_6696a_row1_col4" class="data row1 col4" >4.378832</td>
#       <td id="T_6696a_row1_col5" class="data row1 col5" >89.960217</td>
#     </tr>
#     <tr>
#       <th id="T_6696a_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_6696a_row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_6696a_row2_col1" class="data row2 col1" >28.915970</td>
#       <td id="T_6696a_row2_col2" class="data row2 col2" >5.377357</td>
#       <td id="T_6696a_row2_col3" class="data row2 col3" >0.696074</td>
#       <td id="T_6696a_row2_col4" class="data row2 col4" >2.340047</td>
#       <td id="T_6696a_row2_col5" class="data row2 col5" >39.435568</td>
#     </tr>
#     <tr>
#       <th id="T_6696a_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T_6696a_row3_col0" class="data row3 col0" >{'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}</td>
#       <td id="T_6696a_row3_col1" class="data row3 col1" >34.530357</td>
#       <td id="T_6696a_row3_col2" class="data row3 col2" >5.876254</td>
#       <td id="T_6696a_row3_col3" class="data row3 col3" >0.637063</td>
#       <td id="T_6696a_row3_col4" class="data row3 col4" >2.733370</td>
#       <td id="T_6696a_row3_col5" class="data row3 col5" >36.762157</td>
#     </tr>
#     <tr>
#       <th id="T_6696a_level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T_6696a_row4_col0" class="data row4 col0" >{'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}</td>
#       <td id="T_6696a_row4_col1" class="data row4 col1" >100.022141</td>
#       <td id="T_6696a_row4_col2" class="data row4 col2" >10.001107</td>
#       <td id="T_6696a_row4_col3" class="data row4 col3" >-0.051300</td>
#       <td id="T_6696a_row4_col4" class="data row4 col4" >4.971675</td>
#       <td id="T_6696a_row4_col5" class="data row4 col5" >141.112292</td>
#     </tr>
#   </tbody>
# </table>
# Data: all, Scale X: False, Scale Y: True
# <style type="text/css">
# #T_bab3f_row3_col1, #T_bab3f_row3_col2, #T_bab3f_row3_col3, #T_bab3f_row3_col4, #T_bab3f_row3_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_bab3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bab3f_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_bab3f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bab3f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bab3f_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_bab3f_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_bab3f_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bab3f_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_bab3f_row0_col0" class="data row0 col0" >{'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}</td>
#       <td id="T_bab3f_row0_col1" class="data row0 col1" >113.243008</td>
#       <td id="T_bab3f_row0_col2" class="data row0 col2" >10.641570</td>
#       <td id="T_bab3f_row0_col3" class="data row0 col3" >-0.190260</td>
#       <td id="T_bab3f_row0_col4" class="data row0 col4" >4.473409</td>
#       <td id="T_bab3f_row0_col5" class="data row0 col5" >430.630241</td>
#     </tr>
#     <tr>
#       <th id="T_bab3f_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_bab3f_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T_bab3f_row1_col1" class="data row1 col1" >114.948280</td>
#       <td id="T_bab3f_row1_col2" class="data row1 col2" >10.721394</td>
#       <td id="T_bab3f_row1_col3" class="data row1 col3" >-0.208184</td>
#       <td id="T_bab3f_row1_col4" class="data row1 col4" >4.515626</td>
#       <td id="T_bab3f_row1_col5" class="data row1 col5" >420.907021</td>
#     </tr>
#     <tr>
#       <th id="T_bab3f_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_bab3f_row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_bab3f_row2_col1" class="data row2 col1" >113.776680</td>
#       <td id="T_bab3f_row2_col2" class="data row2 col2" >10.666615</td>
#       <td id="T_bab3f_row2_col3" class="data row2 col3" >-0.195869</td>
#       <td id="T_bab3f_row2_col4" class="data row2 col4" >4.485559</td>
#       <td id="T_bab3f_row2_col5" class="data row2 col5" >377.002716</td>
#     </tr>
#     <tr>
#       <th id="T_bab3f_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T_bab3f_row3_col0" class="data row3 col0" >{'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}</td>
#       <td id="T_bab3f_row3_col1" class="data row3 col1" >113.042076</td>
#       <td id="T_bab3f_row3_col2" class="data row3 col2" >10.632125</td>
#       <td id="T_bab3f_row3_col3" class="data row3 col3" >-0.188148</td>
#       <td id="T_bab3f_row3_col4" class="data row3 col4" >4.468737</td>
#       <td id="T_bab3f_row3_col5" class="data row3 col5" >354.990554</td>
#     </tr>
#     <tr>
#       <th id="T_bab3f_level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T_bab3f_row4_col0" class="data row4 col0" >{'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}</td>
#       <td id="T_bab3f_row4_col1" class="data row4 col1" >114.838364</td>
#       <td id="T_bab3f_row4_col2" class="data row4 col2" >10.716266</td>
#       <td id="T_bab3f_row4_col3" class="data row4 col3" >-0.207028</td>
#       <td id="T_bab3f_row4_col4" class="data row4 col4" >4.511597</td>
#       <td id="T_bab3f_row4_col5" class="data row4 col5" >417.220640</td>
#     </tr>
#   </tbody>
# </table>
# Data: all, Scale X: True, Scale Y: False
# <style type="text/css">
# #T_90049_row1_col1, #T_90049_row1_col2, #T_90049_row1_col3, #T_90049_row1_col4, #T_90049_row3_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_90049">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90049_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_90049_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_90049_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_90049_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_90049_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_90049_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90049_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_90049_row0_col0" class="data row0 col0" >{'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}</td>
#       <td id="T_90049_row0_col1" class="data row0 col1" >28.278002</td>
#       <td id="T_90049_row0_col2" class="data row0 col2" >5.317707</td>
#       <td id="T_90049_row0_col3" class="data row0 col3" >0.702779</td>
#       <td id="T_90049_row0_col4" class="data row0 col4" >2.453648</td>
#       <td id="T_90049_row0_col5" class="data row0 col5" >249.935168</td>
#     </tr>
#     <tr>
#       <th id="T_90049_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_90049_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T_90049_row1_col1" class="data row1 col1" >26.066845</td>
#       <td id="T_90049_row1_col2" class="data row1 col2" >5.105570</td>
#       <td id="T_90049_row1_col3" class="data row1 col3" >0.726020</td>
#       <td id="T_90049_row1_col4" class="data row1 col4" >2.267398</td>
#       <td id="T_90049_row1_col5" class="data row1 col5" >38.692513</td>
#     </tr>
#     <tr>
#       <th id="T_90049_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_90049_row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_90049_row2_col1" class="data row2 col1" >28.915970</td>
#       <td id="T_90049_row2_col2" class="data row2 col2" >5.377357</td>
#       <td id="T_90049_row2_col3" class="data row2 col3" >0.696074</td>
#       <td id="T_90049_row2_col4" class="data row2 col4" >2.340047</td>
#       <td id="T_90049_row2_col5" class="data row2 col5" >39.435568</td>
#     </tr>
#     <tr>
#       <th id="T_90049_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T_90049_row3_col0" class="data row3 col0" >{'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}</td>
#       <td id="T_90049_row3_col1" class="data row3 col1" >34.530357</td>
#       <td id="T_90049_row3_col2" class="data row3 col2" >5.876254</td>
#       <td id="T_90049_row3_col3" class="data row3 col3" >0.637063</td>
#       <td id="T_90049_row3_col4" class="data row3 col4" >2.733370</td>
#       <td id="T_90049_row3_col5" class="data row3 col5" >36.762157</td>
#     </tr>
#     <tr>
#       <th id="T_90049_level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T_90049_row4_col0" class="data row4 col0" >{'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}</td>
#       <td id="T_90049_row4_col1" class="data row4 col1" >31.096512</td>
#       <td id="T_90049_row4_col2" class="data row4 col2" >5.576425</td>
#       <td id="T_90049_row4_col3" class="data row4 col3" >0.673155</td>
#       <td id="T_90049_row4_col4" class="data row4 col4" >2.387234</td>
#       <td id="T_90049_row4_col5" class="data row4 col5" >46.720797</td>
#     </tr>
#   </tbody>
# </table>
# Data: all, Scale X: True, Scale Y: True
# <style type="text/css">
# #T_438e0_row3_col1, #T_438e0_row3_col2, #T_438e0_row3_col3, #T_438e0_row3_col4, #T_438e0_row3_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_438e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_438e0_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_438e0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_438e0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_438e0_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_438e0_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_438e0_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_438e0_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_438e0_row0_col0" class="data row0 col0" >{'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}</td>
#       <td id="T_438e0_row0_col1" class="data row0 col1" >113.226442</td>
#       <td id="T_438e0_row0_col2" class="data row0 col2" >10.640791</td>
#       <td id="T_438e0_row0_col3" class="data row0 col3" >-0.190086</td>
#       <td id="T_438e0_row0_col4" class="data row0 col4" >4.472912</td>
#       <td id="T_438e0_row0_col5" class="data row0 col5" >430.653542</td>
#     </tr>
#     <tr>
#       <th id="T_438e0_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_438e0_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T_438e0_row1_col1" class="data row1 col1" >113.734444</td>
#       <td id="T_438e0_row1_col2" class="data row1 col2" >10.664635</td>
#       <td id="T_438e0_row1_col3" class="data row1 col3" >-0.195425</td>
#       <td id="T_438e0_row1_col4" class="data row1 col4" >4.484908</td>
#       <td id="T_438e0_row1_col5" class="data row1 col5" >375.483704</td>
#     </tr>
#     <tr>
#       <th id="T_438e0_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_438e0_row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_438e0_row2_col1" class="data row2 col1" >113.776680</td>
#       <td id="T_438e0_row2_col2" class="data row2 col2" >10.666615</td>
#       <td id="T_438e0_row2_col3" class="data row2 col3" >-0.195869</td>
#       <td id="T_438e0_row2_col4" class="data row2 col4" >4.485559</td>
#       <td id="T_438e0_row2_col5" class="data row2 col5" >377.002716</td>
#     </tr>
#     <tr>
#       <th id="T_438e0_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T_438e0_row3_col0" class="data row3 col0" >{'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}</td>
#       <td id="T_438e0_row3_col1" class="data row3 col1" >113.042076</td>
#       <td id="T_438e0_row3_col2" class="data row3 col2" >10.632125</td>
#       <td id="T_438e0_row3_col3" class="data row3 col3" >-0.188148</td>
#       <td id="T_438e0_row3_col4" class="data row3 col4" >4.468737</td>
#       <td id="T_438e0_row3_col5" class="data row3 col5" >354.990554</td>
#     </tr>
#     <tr>
#       <th id="T_438e0_level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T_438e0_row4_col0" class="data row4 col0" >{'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}</td>
#       <td id="T_438e0_row4_col1" class="data row4 col1" >113.882851</td>
#       <td id="T_438e0_row4_col2" class="data row4 col2" >10.671591</td>
#       <td id="T_438e0_row4_col3" class="data row4 col3" >-0.196985</td>
#       <td id="T_438e0_row4_col4" class="data row4 col4" >4.489720</td>
#       <td id="T_438e0_row4_col5" class="data row4 col5" >381.785059</td>
#     </tr>
#   </tbody>
# </table>
# Data: all_normalize, Scale X: False, Scale Y: False
# <style type="text/css">
# #T_0540c_row0_col1, #T_0540c_row0_col2, #T_0540c_row0_col3, #T_0540c_row2_col4, #T_0540c_row3_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_0540c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0540c_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_0540c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0540c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0540c_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_0540c_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_0540c_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0540c_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_0540c_row0_col0" class="data row0 col0" >{'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}</td>
#       <td id="T_0540c_row0_col1" class="data row0 col1" >28.025935</td>
#       <td id="T_0540c_row0_col2" class="data row0 col2" >5.293953</td>
#       <td id="T_0540c_row0_col3" class="data row0 col3" >0.705429</td>
#       <td id="T_0540c_row0_col4" class="data row0 col4" >2.448390</td>
#       <td id="T_0540c_row0_col5" class="data row0 col5" >246.129225</td>
#     </tr>
#     <tr>
#       <th id="T_0540c_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_0540c_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T_0540c_row1_col1" class="data row1 col1" >31.728058</td>
#       <td id="T_0540c_row1_col2" class="data row1 col2" >5.632766</td>
#       <td id="T_0540c_row1_col3" class="data row1 col3" >0.666517</td>
#       <td id="T_0540c_row1_col4" class="data row1 col4" >2.651118</td>
#       <td id="T_0540c_row1_col5" class="data row1 col5" >50.003546</td>
#     </tr>
#     <tr>
#       <th id="T_0540c_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_0540c_row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_0540c_row2_col1" class="data row2 col1" >28.933826</td>
#       <td id="T_0540c_row2_col2" class="data row2 col2" >5.379017</td>
#       <td id="T_0540c_row2_col3" class="data row2 col3" >0.695886</td>
#       <td id="T_0540c_row2_col4" class="data row2 col4" >2.342284</td>
#       <td id="T_0540c_row2_col5" class="data row2 col5" >39.433020</td>
#     </tr>
#     <tr>
#       <th id="T_0540c_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T_0540c_row3_col0" class="data row3 col0" >{'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}</td>
#       <td id="T_0540c_row3_col1" class="data row3 col1" >32.085922</td>
#       <td id="T_0540c_row3_col2" class="data row3 col2" >5.664444</td>
#       <td id="T_0540c_row3_col3" class="data row3 col3" >0.662755</td>
#       <td id="T_0540c_row3_col4" class="data row3 col4" >2.642400</td>
#       <td id="T_0540c_row3_col5" class="data row3 col5" >36.117044</td>
#     </tr>
#     <tr>
#       <th id="T_0540c_level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T_0540c_row4_col0" class="data row4 col0" >{'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}</td>
#       <td id="T_0540c_row4_col1" class="data row4 col1" >32.296776</td>
#       <td id="T_0540c_row4_col2" class="data row4 col2" >5.683025</td>
#       <td id="T_0540c_row4_col3" class="data row4 col3" >0.660539</td>
#       <td id="T_0540c_row4_col4" class="data row4 col4" >2.414424</td>
#       <td id="T_0540c_row4_col5" class="data row4 col5" >46.533373</td>
#     </tr>
#   </tbody>
# </table>
# Data: all_normalize, Scale X: False, Scale Y: True
# <style type="text/css">
# #T_c1dc0_row3_col1, #T_c1dc0_row3_col2, #T_c1dc0_row3_col3, #T_c1dc0_row3_col4, #T_c1dc0_row3_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_c1dc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1dc0_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_c1dc0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c1dc0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c1dc0_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_c1dc0_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_c1dc0_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1dc0_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_c1dc0_row0_col0" class="data row0 col0" >{'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}</td>
#       <td id="T_c1dc0_row0_col1" class="data row0 col1" >113.207041</td>
#       <td id="T_c1dc0_row0_col2" class="data row0 col2" >10.639880</td>
#       <td id="T_c1dc0_row0_col3" class="data row0 col3" >-0.189882</td>
#       <td id="T_c1dc0_row0_col4" class="data row0 col4" >4.472881</td>
#       <td id="T_c1dc0_row0_col5" class="data row0 col5" >430.600604</td>
#     </tr>
#     <tr>
#       <th id="T_c1dc0_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_c1dc0_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T_c1dc0_row1_col1" class="data row1 col1" >113.864410</td>
#       <td id="T_c1dc0_row1_col2" class="data row1 col2" >10.670727</td>
#       <td id="T_c1dc0_row1_col3" class="data row1 col3" >-0.196791</td>
#       <td id="T_c1dc0_row1_col4" class="data row1 col4" >4.489192</td>
#       <td id="T_c1dc0_row1_col5" class="data row1 col5" >379.741359</td>
#     </tr>
#     <tr>
#       <th id="T_c1dc0_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_c1dc0_row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_c1dc0_row2_col1" class="data row2 col1" >113.776413</td>
#       <td id="T_c1dc0_row2_col2" class="data row2 col2" >10.666603</td>
#       <td id="T_c1dc0_row2_col3" class="data row2 col3" >-0.195866</td>
#       <td id="T_c1dc0_row2_col4" class="data row2 col4" >4.485551</td>
#       <td id="T_c1dc0_row2_col5" class="data row2 col5" >377.000976</td>
#     </tr>
#     <tr>
#       <th id="T_c1dc0_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T_c1dc0_row3_col0" class="data row3 col0" >{'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}</td>
#       <td id="T_c1dc0_row3_col1" class="data row3 col1" >113.145546</td>
#       <td id="T_c1dc0_row3_col2" class="data row3 col2" >10.636990</td>
#       <td id="T_c1dc0_row3_col3" class="data row3 col3" >-0.189236</td>
#       <td id="T_c1dc0_row3_col4" class="data row3 col4" >4.470571</td>
#       <td id="T_c1dc0_row3_col5" class="data row3 col5" >357.666183</td>
#     </tr>
#     <tr>
#       <th id="T_c1dc0_level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T
row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_666fd_row2_col1" class="data row2 col1" >27.068531</td>
#       <td id="T_666fd_row2_col2" class="data row2 col2" >5.202743</td>
#       <td id="T_666fd_row2_col3" class="data row2 col3" >0.715492</td>
#       <td id="T_666fd_row2_col4" class="data row2 col4" >2.242830</td>
#       <td id="T_666fd_row2_col5" class="data row2 col5" >38.107073</td>
#     </tr>
#     <tr>
#       <th id="T_666fd_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T_666fd_row3_col0" class="data row3 col0" >{'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 300}</td>
#       <td id="T_666fd_row3_col1" class="data row3 col1" >28.075428</td>
#       <td id="T_666fd_row3_col2" class="data row3 col2" >5.298625</td>
#       <td id="T_666fd_row3_col3" class="data row3 col3" >0.704908</td>
#       <td id="T_666fd_row3_col4" class="data row3 col4" >2.311099</td>
#       <td id="T_666fd_row3_col5" class="data row3 col5" >41.121554</td>
#     </tr>
#     <tr>
#       <th id="T_666fd_level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T_666fd_row4_col0" class="data row4 col0" >{'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}</td>
#       <td id="T_666fd_row4_col1" class="data row4 col1" >31.889738</td>
#       <td id="T_666fd_row4_col2" class="data row4 col2" >5.647100</td>
#       <td id="T_666fd_row4_col3" class="data row4 col3" >0.664817</td>
#       <td id="T_666fd_row4_col4" class="data row4 col4" >2.409689</td>
#       <td id="T_666fd_row4_col5" class="data row4 col5" >45.335826</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance_normalize, Scale X: False, Scale Y: True
# <style type="text/css">
# #T_cf7d3_row0_col1, #T_cf7d3_row0_col2, #T_cf7d3_row0_col3, #T_cf7d3_row2_col4, #T_cf7d3_row2_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_cf7d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf7d3_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_cf7d3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_cf7d3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_cf7d3_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_cf7d3_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_cf7d3_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf7d3_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_cf7d3_row0_col0" class="data row0 col0" >{'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}</td>
#       <td id="T_cf7d3_row0_col1" class="data row0 col1" >113.794089</td>
#       <td id="T_cf7d3_row0_col2" class="data row0 col2" >10.667431</td>
#       <td id="T_cf7d3_row0_col3" class="data row0 col3" >-0.196052</td>
#       <td id="T_cf7d3_row0_col4" class="data row0 col4" >4.486020</td>
#       <td id="T_cf7d3_row0_col5" class="data row0 col5" >434.959762</td>
#     </tr>
#     <tr>
#       <th id="T_cf7d3_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_cf7d3_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T_cf7d3_row1_col1" class="data row1 col1" >113.800591</td>
#       <td id="T_cf7d3_row1_col2" class="data row1 col2" >10.667736</td>
#       <td id="T_cf7d3_row1_col3" class="data row1 col3" >-0.196121</td>
#       <td id="T_cf7d3_row1_col4" class="data row1 col4" >4.487869</td>
#       <td id="T_cf7d3_row1_col5" class="data row1 col5" >378.001070</td>
#     </tr>
#     <tr>
#       <th id="T_cf7d3_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_cf7d3_row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_cf7d3_row2_col1" class="data row2 col1" >113.802933</td>
#       <td id="T_cf7d3_row2_col2" class="data row2 col2" >10.667846</td>
#       <td id="T_cf7d3_row2_col3" class="data row2 col3" >-0.196145</td>
#       <td id="T_cf7d3_row2_col4" class="data row2 col4" >4.485953</td>
#       <td id="T_cf7d3_row2_col5" class="data row2 col5" >377.411366</td>
#     </tr>
#     <tr>
#       <th id="T_cf7d3_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T_cf7d3_row3_col0" class="data row3 col0" >{'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 300}</td>
#       <td id="T_cf7d3_row3_col1" class="data row3 col1" >113.875038</td>
#       <td id="T_cf7d3_row3_col2" class="data row3 col2" >10.671225</td>
#       <td id="T_cf7d3_row3_col3" class="data row3 col3" >-0.196903</td>
#       <td id="T_cf7d3_row3_col4" class="data row3 col4" >4.488061</td>
#       <td id="T_cf7d3_row3_col5" class="data row3 col5" >379.805803</td>
#     </tr>
#     <tr>
#       <th id="T_cf7d3_level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T_cf7d3_row4_col0" class="data row4 col0" >{'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}</td>
#       <td id="T_cf7d3_row4_col1" class="data row4 col1" >113.893074</td>
#       <td id="T_cf7d3_row4_col2" class="data row4 col2" >10.672070</td>
#       <td id="T_cf7d3_row4_col3" class="data row4 col3" >-0.197093</td>
#       <td id="T_cf7d3_row4_col4" class="data row4 col4" >4.488342</td>
#       <td id="T_cf7d3_row4_col5" class="data row4 col5" >381.170154</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance_normalize, Scale X: True, Scale Y: False
# <style type="text/css">
# #T_efce4_row1_col1, #T_efce4_row1_col2, #T_efce4_row1_col3, #T_efce4_row2_col4, #T_efce4_row2_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_efce4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efce4_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_efce4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_efce4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_efce4_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_efce4_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_efce4_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efce4_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_efce4_row0_col0" class="data row0 col0" >{'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}</td>
#       <td id="T_efce4_row0_col1" class="data row0 col1" >27.604443</td>
#       <td id="T_efce4_row0_col2" class="data row0 col2" >5.253993</td>
#       <td id="T_efce4_row0_col3" class="data row0 col3" >0.709859</td>
#       <td id="T_efce4_row0_col4" class="data row0 col4" >2.258488</td>
#       <td id="T_efce4_row0_col5" class="data row0 col5" >255.810270</td>
#     </tr>
#     <tr>
#       <th id="T_efce4_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_efce4_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T_efce4_row1_col1" class="data row1 col1" >26.023556</td>
#       <td id="T_efce4_row1_col2" class="data row1 col2" >5.101329</td>
#       <td id="T_efce4_row1_col3" class="data row1 col3" >0.726475</td>
#       <td id="T_efce4_row1_col4" class="data row1 col4" >2.255879</td>
#       <td id="T_efce4_row1_col5" class="data row1 col5" >39.517286</td>
#     </tr>
#     <tr>
#       <th id="T_efce4_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_efce4_row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_efce4_row2_col1" class="data row2 col1" >27.068501</td>
#       <td id="T_efce4_row2_col2" class="data row2 col2" >5.202740</td>
#       <td id="T_efce4_row2_col3" class="data row2 col3" >0.715492</td>
#       <td id="T_efce4_row2_col4" class="data row2 col4" >2.242835</td>
#       <td id="T_efce4_row2_col5" class="data row2 col5" >38.105410</td>
#     </tr>
#     <tr>
#       <th id="T_efce4_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T_efce4_row3_col0" class="data row3 col0" >{'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 300}</td>
#       <td id="T_efce4_row3_col1" class="data row3 col1" >28.076588</td>
#       <td id="T_efce4_row3_col2" class="data row3 col2" >5.298735</td>
#       <td id="T_efce4_row3_col3" class="data row3 col3" >0.704896</td>
#       <td id="T_efce4_row3_col4" class="data row3 col4" >2.311115</td>
#       <td id="T_efce4_row3_col5" class="data row3 col5" >41.121751</td>
#     </tr>
#     <tr>
#       <th id="T_efce4_level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T_efce4_row4_col0" class="data row4 col0" >{'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}</td>
#       <td id="T_efce4_row4_col1" class="data row4 col1" >30.499727</td>
#       <td id="T_efce4_row4_col2" class="data row4 col2" >5.522656</td>
#       <td id="T_efce4_row4_col3" class="data row4 col3" >0.679427</td>
#       <td id="T_efce4_row4_col4" class="data row4 col4" >2.382368</td>
#       <td id="T_efce4_row4_col5" class="data row4 col5" >44.358620</td>
#     </tr>
#   </tbody>
# </table>
# Data: importance_normalize, Scale X: True, Scale Y: True
# <style type="text/css">
# #T_f42a7_row1_col1, #T_f42a7_row1_col2, #T_f42a7_row1_col3, #T_f42a7_row1_col4, #T_f42a7_row1_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_f42a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f42a7_level0_col0" class="col_heading level0 col0" >Best Params</th>
#       <th id="T_f42a7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f42a7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f42a7_level0_col3" class="col_heading level0 col3" >R^2</th>
#       <th id="T_f42a7_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_f42a7_level0_col5" class="col_heading level0 col5" >sMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f42a7_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_f42a7_row0_col0" class="data row0 col0" >{'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}</td>
#       <td id="T_f42a7_row0_col1" class="data row0 col1" >113.785253</td>
#       <td id="T_f42a7_row0_col2" class="data row0 col2" >10.667017</td>
#       <td id="T_f42a7_row0_col3" class="data row0 col3" >-0.195959</td>
#       <td id="T_f42a7_row0_col4" class="data row0 col4" >4.485851</td>
#       <td id="T_f42a7_row0_col5" class="data row0 col5" >434.913205</td>
#     </tr>
#     <tr>
#       <th id="T_f42a7_level0_row1" class="row_heading level0 row1" >Linear Regression</th>
#       <td id="T_f42a7_row1_col0" class="data row1 col0" >{}</td>
#       <td id="T_f42a7_row1_col1" class="data row1 col1" >113.720322</td>
#       <td id="T_f42a7_row1_col2" class="data row1 col2" >10.663973</td>
#       <td id="T_f42a7_row1_col3" class="data row1 col3" >-0.195277</td>
#       <td id="T_f42a7_row1_col4" class="data row1 col4" >4.485246</td>
#       <td id="T_f42a7_row1_col5" class="data row1 col5" >375.324368</td>
#     </tr>
#     <tr>
#       <th id="T_f42a7_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_f42a7_row2_col0" class="data row2 col0" >{'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_f42a7_row2_col1" class="data row2 col1" >113.802933</td>
#       <td id="T_f42a7_row2_col2" class="data row2 col2" >10.667846</td>
#       <td id="T_f42a7_row2_col3" class="data row2 col3" >-0.196145</td>
#       <td id="T_f42a7_row2_col4" class="data row2 col4" >4.485953</td>
#       <td id="T_f42a7_row2_col5" class="data row2 col5" >377.411342</td>
#     </tr>
#     <tr>
#       <th id="T_f42a7_level0_row3" class="row_heading level0 row3" >XGBoost Regressor</th>
#       <td id="T_f42a7_row3_col0" class="data row3 col0" >{'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 300}</td>
#       <td id="T_f42a7_row3_col1" class="data row3 col1" >113.875099</td>
#       <td id="T_f42a7_row3_col2" class="data row3 col2" >10.671228</td>
#       <td id="T_f42a7_row3_col3" class="data row3 col3" >-0.196904</td>
#       <td id="T_f42a7_row3_col4" class="data row3 col4" >4.488061</td>
#       <td id="T_f42a7_row3_col5" class="data row3 col5" >379.807377</td>
#     </tr>
#     <tr>
#       <th id="T_f42a7_level0_row4" class="row_heading level0 row4" >K-Neighbors Regressor</th>
#       <td id="T_f42a7_row4_col0" class="data row4 col0" >{'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}</td>
#       <td id="T_f42a7_row4_col1" class="data row4 col1" >113.826775</td>
#       <td id="T_f42a7_row4_col2" class="data row4 col2" >10.668963</td>
#       <td id="T_f42a7_row4_col3" class="data row4 col3" >-0.196396</td>
#       <td id="T_f42a7_row4_col4" class="data row4 col4" >4.487460</td>
#       <td id="T_f42a7_row4_col5" class="data row4 col5" >379.347086</td>
#     </tr>
#   </tbody>
# </table>
